# %% [markdown]
# 1. What is Python?
# It's a programming language, created by Guido van Rossum, and released in 1991.
# 2. Major applications
# --  web development (server-side)
# --  software development
# --  mathematics
# --  system scripting.

# %%
print('Hello World')

# %% [markdown]
# # Variables
#
# 1. A varaible in python is used for assigning values to it.
# 2. Different types of variables are float, int, string, etc.

# %%
x=3 #x is an int variable
print(x)
type(x) #type function helps to detect the type of the variable
# Out:
# 3
# int

# %%
y='happy' #y is a string variable
print(y)
type(y)
# Out:
# happy
# str

# %%
z=0.03 # z is a float value
print(z)
type(z)
# Out:
# 0.03
# float

# %% [markdown]
# ### Variable Names
# A variable can have a short name (like x and y) or a more descriptive name (age, carname, total_volume). Rules for Python variables:
#
#     A variable name must start with a letter or the underscore character
#     A variable name cannot start with a number
#     A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
#     Variable names are case-sensitive (age, Age and AGE are three different variables)

# %%
# Legal Variable use case examples
myvar = "John"
my_var = "John"
_my_var = "John"
myVar = "John"
MYVAR = "John"
myvar2 = "John"

# %%
# Illegal variable use case examples
2myvar = "John"
my-var = "John"
my var = "John"
# Out:
#   File "<ipython-input-8-c2bf45d05c49>", line 2
#     2myvar = "John"
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Data-Types in Python
# In programming, data type is an important concept.
#
# Variables can store data of different types, and different types can do different things.
#
# Python has the following data types built-in by default, in these categories:
#
# Text Type: 	**str**
#
# Numeric Types: 	**int, float, complex**
#
# Sequence Types: 	**list, tuple, range**
#
# Mapping Type: 	**dict**
#
# Set Types: 	**set, frozenset**
#
# Boolean Type: 	**bool**
#
# Binary Types: 	**bytes, bytearray, memoryview**
#
# None Type: 	NoneType

# %%
x = "Hello World"
type(x)
# Out:
# str

# %%
x = 20
type(x)
# Out:
# int

# %%
x = 20.5
type(x)
# Out:
# float

# %%
x = 1j
type(x)
# Out:
# complex

# %%
x = ["apple", "banana", "cherry"]
type(x)
# Out:
# list

# %%
x = ("apple", "banana", "cherry")
type(x)
# Out:
# tuple

# %%
x = range(6)
type(x)
# Out:
# range

# %%
x = {"name" : "John", "age" : 36}
type(x)
# Out:
# dict

# %%
x = {"apple", "banana", "cherry"}
type(x)
# Out:
# set

# %%
x = True
type(x)
# Out:
# bool

# %%
x = b"Hello"
type(x)
# Out:
# bytes

# %%
x = bytearray(5)
type(x)
# Out:
# bytearray

# %%
x = None
type(x)
# Out:
# NoneType

# %% [markdown]
# # Python Operators

# %% [markdown]
# Python Arithmetic Operators
#
# Arithmetic operators are used with numeric values to perform common mathematical operations:
# ![Screenshot 2022-12-16 at 09.34.45.png](data:image/png;base64,...)

# %% [markdown]
# Python Assignment Operators
#
# Assignment operators are used to assign values to variables:
# ![Screenshot 2022-12-16 at 09.38.14.png](data:image/png;base64,...)

# %% [markdown]
#  Python Comparison Operator
#
#  Comparison operators are used to compare two values:
#
#  ![Screenshot 2022-12-16 at 09.40.03.png](data:image/png;base64,...)

# %% [markdown]
# Python Logical Operators
#
# Logical operators are used to combine conditional statements:
#
# ![Screenshot 2022-12-16 at 09.41.14.png](data:image/png;base64,...)

# %% [markdown]
# Python Identity Operators
#
# Identity operators are used to compare the objects, not if they are equal, but if they are actually the same object, with the same memory location:
#
# ![Screenshot 2022-12-16 at 09.42.34.png](data:image/png;base64,...)

# %% [markdown]
# Python Membership Operators
#
# Membership operators are used to test if a sequence is presented in an object:
# ![Screenshot 2022-12-16 at 09.43.42.png](data:image/png;base64,...)

# %% [markdown]
# Python Bitwise Operators
#
# Bitwise operators are used to compare (binary) numbers:
#
# ![Screenshot 2022-12-16 at 09.45.41.png](data:image/png;base64,...)

# %% [markdown]
# #Loops in Python
#
# 1. If..Elif..Else
# 2. Nested if
# 3. While
# 4. For

# %%
#If..Elif..Else
a = 200
b = 33
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
else:
  print("a is greater than b")
# Out:
# a is greater than b

# %%
#Nested If
i = 13

if (i == 13):
	# First if statement
	if (i < 15):
		print ("i is smaller than 15")
		
	# Nested - if statement
	# Will only be executed if statement above
	# it is true
	if (i < 12):
		print ("i is smaller than 12 too")
	else:
		print ("i is greater than 12 and smaller than 15")
# Out:
# i is smaller than 15
# i is greater than 12 and smaller than 15

# %%
#While Loop
# initialize the variable
i = 1
n = 5

# while loop from i = 1 to 5
while i <= n:
    print(i)
    i = i + 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#For Loops
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  if x == "banana":
    break
  print(x)
# Out:
# apple
